# %% [raw]
# ---
# title: "Simple Python"
# author: "TACT"
# date: 2019-04-20
# description: "-"
# type: technical_note
# draft: false
# ---

# %%
print('Hello Toronto')
# Out:
# Hello Toronto

# %%
print(2)
# Out:
# 2
