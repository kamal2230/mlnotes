# %% [raw]
# ---
# title: "Heatmap"
# author: "Kamal"
# date: 2020-08-12
# description: "-"
# type: technical_note
# draft: false
# ---

# %%
import pandas as pd
import seaborn as sb

# %%
df = pd.read_csv("D:/Datasets/Wine Quality/winequality-white.csv",sep=";")
df.sample(5)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2694            6.2              0.28         0.27            10.3      0.030
# 2542            8.9              0.27         0.34            10.7      0.029
# 1170            7.7              0.25         0.43             4.5      0.062
# 4622            6.5              0.50         0.22             4.1      0.036
# 3681            7.0              0.22         0.26             9.2      0.027
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 2694                 26.0                 108.0  0.99388  3.20       0.36
# 2542                 19.5                 166.0  0.99669  3.13       0.48
# 1170                 20.0                 115.0  0.99660  3.38       0.50
# 4622                 35.0                 131.0  0.99020  3.26       0.55
# 3681                 37.0                 122.0  0.99228  3.06       0.34
#
#       alcohol  quality
# 2694     10.7        6
# 2542     10.6        5
# 1170      9.9        6
# 4622     13.0        7
# 3681     12.5        8

# %%
d = df.corr().round(2)
sb.set(rc={"figure.figsize":(20,15)}) #plot-size
sb.heatmap(data = d,annot = True)
